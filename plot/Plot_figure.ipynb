# %%
import numpy as np 
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
import os

# %%
pwd = os.getcwd()
path_1 = os.path.dirname(pwd) + '/result/18_09_20_seed_108_init/data.csv'
f = open(path_1, encoding='utf-8')
result_1 = pd.read_csv(f)
f.close()

path_2 = os.path.dirname(pwd) + '/result/11_09_20_50trials_kappa_2/data.csv'
f = open(path_2, encoding='utf-8')
result_2 = pd.read_csv(f)
f.close()

path_3 = os.path.dirname(pwd) + '/result/10_08_20_20trials/data.csv'
f = open(path_3, encoding='utf-8')
result_3 = pd.read_csv(f)
f.close()

voltage_1 = result_1['voltage_45'].tolist()
voltage_2 = result_2['voltage'].tolist()
voltage_3 = result_3['voltage'].tolist()

list = [6.8, 7.6, 8.0, 8.0, 8.3, 6.8, 8.4, 6.8, 7.8, 7.8]
for item in list:
    voltage_3.append(item)

print(len(voltage_1))
# path
# print(os.path.abspath(os.path.dirname(os.path.dirname('__file__'))))
# print(os.path.abspath(os.path.dirname('__file__')))
# Out:
# 20

# %%
iteration = 20
# iteration = 50



x_axis = np.linspace(1, iteration, iteration)
fig = plt.figure()

# for i in range(30):
#     voltage_3[i] = 3* voltage_3[i]

# plt.plot(x_axis, voltage_1,'b.-', label='kappa=5', linewidth=0.5)
# plt.plot(x_axis, voltage_2,'m.-.', label='kappa=2', linewidth=0.5)
# plt.legend(loc='upper left', fontsize=6, frameon=False)

plt.xticks(range(1,21))
plt.plot(x_axis, voltage_1,'b.-.', linewidth=0.8)
# plt.legend(loc='upper left', fontsize=6, frameon=False)

plt.title('Sequential CoCaBo with 5 Shapes')
plt.xlabel('Experiment Number')
plt.ylabel('Voltage (V)')
# plt.savefig('Sequential CoCaBo with 5 Shapes.png', dpi=500,bbox_inches = 'tight')
plt.show()

# %%
iteration = 10
print("live plotting")
print(iteration)
x_axis = np.linspace(1, iteration, iteration)
v = [6.8, 7.6, 8.0, 8.0, 8.3, 6.8, 8.4, 6.8, 7.8, 7.8]
r_f = []
for i in range(len(v)):
    r = 100/v[i]*(15-v[i])
    r_f.append(r)

plt.scatter(x_axis, v, s=20, c='blue', marker='.')
plt.yticks(np.arange(0, 12, step=2))
plt.

# plt.subplot(2)
# plt.scatter(x_axis, r_f, s=20, c='red', marker='.')
# plt.yticks(np.arange(0, 12, step=2))

plt.suptitle("Experiment 1 - Optimise Voltage")
plt.show()
# Out:
# live plotting
# 10
